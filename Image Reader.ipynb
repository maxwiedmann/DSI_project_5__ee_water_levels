# %%
pip install rasterio
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\inser\anaconda3\envs\dsi\python.exe' 'C:\Users\inser\anaconda3\envs\dsi\lib\site-packages\pip\_vendor\pep517\_in_process.py' get_requires_for_build_wheel 'C:\Users\inser\AppData\Local\Temp\tmpn6qn6raz'
#        cwd: C:\Users\inser\AppData\Local\Temp\pip-install-93bbou57\rasterio
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# ...

# %%
# Read uncut tif.

import matplotlib.pyplot as plt, numpy as np
import rasterio as rio
with rio.open("./imageToDriveExamplescale100_0.tif") as img :
    imgnp = img.read()#out_dtype = 'uint16')
    imgmeta = img.meta
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/rasterio/__init__.py:218: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
img = rio.open("./imageToDriveExamplescale100_0.tif")

# %%
print(imgnp.shape)
print(imgnp.size)
# Out:
# (2, 192, 193)
# 74112

# %%
imgnp[:1]
# Out:
# array([[[1072775153, 1066614675, 1061568326, ..., 1192642326,
#          1209813020, 1180780129],
#         [1088700644, 1071333339, 1041186319, ..., 1217546386,
#          1163085139, 1227508010],
#         [1075462170, 1090994439, 1081229426, ..., 1102856636,
#          1228294454, 1142244373],
#         ...,
#         [1043545651, 1120617163, 1086734534, ..., 1063206751,
#          1103446469, 1073692671],
#         [1042562596, 1074020356, 1095450955, ..., 1031748991,
#          1122058977, 1108754966],
#         [1078870094, 1095516492, 1149387906, ..., 1058094865,
#          1122714347, 1079197779]]], dtype=uint32)

# %%
imgarray = np.array(img)
imgarray
# Out:
# array(<open DatasetReader name='./imageToDriveExamplescale100_0.tif' mode='r'>,
#       dtype=object)

# %%
plt.imshow(img.read(1))#, cmap='pink')
#plt.image.AxesImage
plt.show()

# %%
np.sum(imgarray, axis = 0)
# Out:
# <closed DatasetReader name='./imageToDriveExamplescale100_0.tif' mode='r'>

# %%
import pandas as pd
pd.DataFrame(imgarray)

# %% [markdown]
# ---

# %%
pip install ubelt
# Out:
# ...
#      |████████████████████████████████| 126 kB 1.5 MB/s eta 0:00:01
# ...
#   Created wheel for ordered-set: filename=ordered_set-4.0.2-py2.py3-none-any.whl size=8209 sha256=062b98b94bf72d94f9991e100e7d66eb1085bfbff16adcf1c24e1dfe7b67177e
#   Stored in directory: /Users/christophervolpacchio/Library/Caches/pip/wheels/73/2b/f6/26e9f84153c25050fe7c09e88f8e32a6be3c7034a38c418319
# Successfully built ordered-set
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---

# %%
import numpy as np, matplotlib.pyplot as plt
#from zipfile import ZipFile
from PIL import Image

#img = ZipFile("./downloads_ancillary_downloadWaterData_PythonV3_2019.zip", mode = 'r', )
img = "./imageToDriveExamplePython.tif"
#img = img.read()
img = Image.open(img, mode = 'r')
img = np.array(img)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-6-9cb148425b29> in <module>
#       6 img = "./imageToDriveExamplePython.tif"
#       7 #img = img.read()
# ----> 8 img = Image.open(img, mode = 'r')
#       9 img = np.array(img)
#
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2860         warnings.warn(message)
#    2861     raise UnidentifiedImageError(
# -> 2862         "cannot identify image file %r" % (filename if filename else fp)
#    2863     )
#    2864
#
# UnidentifiedImageError: cannot identify image file './imageToDriveExamplePython.tif'

# %%
def rgb_array(np_array):
    arrays = []
    for i in np_array:
        for a in i:
            a = list(a[:3])
            arrays.append(a)
    return pd.DataFrame(arrays, columns = ['r','g','b'])

# %%
df = rgb_array(img[:3000])

# %%
df['r'].value_counts()
# Out:
# 255    13283557
# 0       1626882
# 51        44394
# 45        40590
# 50         4505
# 46           63
# 5             9
# Name: r, dtype: int64

# %%
img = np.array(img)
img[:1]
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8)

# %%
set(np.bincount(img.ravel()))
# Out:
# {0, 6, 1461, 1479, 40410, 219651, 274548, 15877221, 83585224}

# %%
import imageio

# %matplotlib inline

# %%
pic = imageio.imread('./test_img.png')
plt.figure(figsize = (5,5))
plt.imshow(pic);

# %%
imageio?
pic.shape
# Out:
# (5000, 5000, 4)
