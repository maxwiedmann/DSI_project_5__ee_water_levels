# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../Charts/data/livermore_water_levels.csv')
df.head()
# Out:
#   system:time_start  waterArea
# 0       Apr 9, 2013     15.636
# 1      Apr 16, 2013     15.056
# 2      May 27, 2013      0.000
# 3       Jun 3, 2013     14.853
# 4      Jun 19, 2013     14.780

# %%
df['dateTime'] = pd.to_datetime(df['system:time_start'])
df = df.drop(columns = ['system:time_start'])
df = df.set_index('dateTime')
df.head()
# Out:
#             waterArea
# dateTime
# 2013-04-09     15.636
# 2013-04-16     15.056
# 2013-05-27      0.000
# 2013-06-03     14.853
# 2013-06-19     14.780

# %%
df = df[df['waterArea']>0]
df.plot()
# Out:
# <AxesSubplot:xlabel='dateTime'>

# %%
med = df['waterArea'].rolling(5).median()

plt.plot(med)
df.plot()
# Out:
# <AxesSubplot:xlabel='dateTime'>
